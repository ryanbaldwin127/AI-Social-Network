# %% [markdown]
# Used to create the dictionary needed to mine to commments for the human prs.

# %%
import pandas as pd
import json

# %%
human_prs = pd.read_parquet('./data/human_pull_request.parquet')

# %%
human_prs.head(10)
# Out:
#            id  number                                              title  \
# 0  2336888723   85268              feat(aci): add automations index page
# 1  2447123365   89131  ref(insights): Make use of `<FeatureBadge>` fo...
# 2  2438086945   88748  :bug: fix: update how we fetch workflow_id and...
# 3  2265431531   83085         fix(org-stats): Require project membership
# 4  2332333882   85102  ref(consumers): Rename parallel -> batched-par...
# 5  2486573779   90516  ref(perf-issues): Consolidate File IO override...
# 6  2474210990   90082  feat(compare): Add timestamp column to sample ...
# 7  2404610772   87421  feat(tsc): Replace SessionsRequest w/ useSessi...
# 8  2354374131   85761  ref(crons): Remove time restriction on uptime ...
# 9  2564963212   92762  feat(insights): update ux for open in explore ...
#
#             user   user_id   state            created_at  \
# 0      ameliahsu  55610339  closed  2025-02-14T19:04:59Z
# ...

# %%
def create_dict(prs):
    #set all keys with unlinked empty lists as values
    all_repos = prs["repo_url"].apply(get_repo).unique()
    prs_dict = {repo:[] for repo in all_repos}
    
    #loop through all prs and add them to corresponding repo
    for pr in prs.iterrows():
        pr = pr[1]
        repo = '/'.join(pr["repo_url"].split('/')[-2:])
        pr_num = pr["number"]
        
        prs_dict[repo].append(pr_num)
        
    #order prs
    for key in prs_dict:
        prs_dict[key].sort()
    
    return prs_dict

# %%
prs_dict = create_dict(human_prs)
print(prs_dict)
# Out:
# {'getsentry/sentry': [83085, 83789, 84390, 85102, 85268, 85352, 85761, 86438, 87169, 87421, 87963, 88748, 89131, 89212, 89622, 90082, 90516, 92762, 92785, 94465], 'mediar-ai/terminator': [18, 39, 57, 61, 76, 98, 135, 150], 'BoundaryML/baml': [1335, 1424, 1909, 1972], 'getsentry/sentry-cli': [2384], 'getsentry/sentry-javascript': [14887, 15043, 15226, 15796, 15909, 16059, 16449], 'activepieces/activepieces': [7565], 'langfuse/langfuse': [5073, 5075, 5814, 5851, 5884, 5986, 6055, 6563, 6817, 6858, 7541], 'elie222/inbox-zero': [303, 334, 393, 445, 519], 'volcengine/verl': [1911], 'risingwavelabs/risingwave': [19989, 21323, 21502, 21968, 22258], 'BerriAI/litellm': [8065, 8227, 8523, 8947, 9046, 9097, 10456, 10700, 10903], 'Brooooooklyn/canvas': [1007], 'oven-sh/bun': [16091, 16093, 16095, 16173, 16223, 16229, 16232, 16263, 16279, 16324, 16348, 16351, 16368, 16399, 16486, 16489, 16553, 16554, 16576, 16585, 16586, 16635, 16824, 16830, 16857, 16954, 16955, 16993, 17122, 17169, 17197, 17207,
# ...

# %%
with open("human_prs_to_mine.json", "w") as file:
    json.dump(prs_dict, file, indent=4)
